# %%
distance = {
    "high" : "99",
    "low" : "99.9",
    "staight" : "30 AU"
}

def main():
    enter = input("Enter a enter: ")
# convert string to number, make sure run fuction def convert
    try:
        au = float(distance[enter])
# handle the unexpected situation,and inform user
    except KeyError:
        print(f"'{enter}' is not in distance")
        return
    except ValueError:
        print(f"'can not convert '{distance[enter]}' to float")
        return
        
    m = convert(au)
    print(f"{m} m away")

def convert(au):
    return au * 99

main()
# Out:
# Enter a enter:  staight
# 'can not convert '30 AU' to float
