# %%
“““

Equilibrium Index in Array

inspired by TheAlgorithms
Reference: https://www.geeksforgeeks.org/equilibrium-index-of-an-array/

this was rewritten from scratch for personal learning and practicing.

    """

# %%
"""

Given an array arr[] of size n, the task is to return an equilibrium index (if any) or -1 if no equilibrium index exists. The equilibrium index of an array is an index such that the sum of all elements at lower indexes equals the sum of all elements at higher indexes. When the index is at the start of the array, the left sum is 0, and when it's at the end, the right sum is 0.

Note: If multiple equilibrium indices exist, return the first one encountered from left to right.

Examples:

Input: arr[] = [1, 2, 0, 3]
Output: 2
Explanation: The sum of left of index 2 is 1 + 2 = 3 and sum on right of index 2 is 3.

Input: arr[] = [1, 1, 1, 1]
Output: -1 
Explanation: There is no equilibrium index in the array.

"""

# %%
# Error1: def Equilibrum index(arr:list[int]) ->int
# Error2: total_right_sum() = sum(arr)
# Error3: grammar. for.. in..:   if():   def():   else:

# %%
def Equilibrum_index(arr:list[int]) ->int
    total_right_sum = sum(arr)
    left_sum = 0
    for i,number in enumerate(arr)
        total_right_sum() -= number
        if total_right_sum() == left_sum
           return i
        else
            left_sum += number
    
return -1
# Out:
#   Cell In[4], line 11
#     return -1
#     ^
# SyntaxError: 'return' outside function

# %%
def Equilibrum_index(arr:list[int]) ->int:
    total_right_sum = sum(arr)
    left_sum = 0
    for i,number in enumerate(arr):
        total_right_sum -= number
        if total_right_sum == left_sum:
           return i
        else: 
            left_sum += number
    
    return -1

# %%
print(Equilibrum_index([1,2,0,3]))
print(Equilibrum_index([1,1,1,1,1]))
# Out:
# 2
# 2

# %%
def Equilibrum_index(arr:list[int]) ->int:
    total_right_sum = sum(arr)
    left_sum = 0
    for i,number in enumerate(arr):
        total_right_sum -= number
        if total_right_sum == left_sum:
           return i
        
        left_sum += number
    
    return -1

# %%
print(Equilibrum_index([1,2,0,3]))
print(Equilibrum_index([1,1,1,1,1]))
# Out:
# 2
# 2
